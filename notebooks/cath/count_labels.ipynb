# %%
import os, sys
sys.path.append(os.path.join(os.getcwd(), '../..'))

from collections import Counter
import pandas as pd

# %%
df = pd.read_csv('../../data/cath/train.csv', sep=' ')
counter = Counter(df.label.to_list()) 
counter.most_common()
# Out:
# [(6665, 200),
#  (3918, 165),
#  (2321, 154),
#  (4932, 149),
#  (2299, 137),
#  (6949, 134),
#  (4915, 128),
#  (4917, 111),
#  (3576, 110),
#  (6930, 109),
#  (6857, 108),
#  (5586, 102),
#  (6621, 101),
#  (6713, 100),
#  (3243, 96),
#  (2303, 90),
#  (6618, 83),
#  (4766, 83),
#  (3259, 80),
#  (3574, 80),
#  (5817, 80),
#  (2238, 75),
#  (6861, 74),
#  (4928, 69),
#  (4031, 69),
#  (6586, 67),
#  (6582, 66),
#  (4954, 66),
#  (2298, 64),
#  (5150, 64),
#  (6955, 64),
#  (4789, 61),
#  (5795, 60),
#  (5750, 58),
#  (4906, 58),
#  (3591, 58),
#  (3953, 58),
#  (2035, 57),
#  (3173, 55),
#  (3957, 55),
#  (2248, 54),
#  (5845, 54),
#  (6632, 54),
#  (6894, 54),
#  (2262, 54),
#  (5674, 53),
#  (6965, 53),
#  (6671, 52),
#  (6613, 52),
#  (1986, 52),
#  (3620, 50),
#  (5186, 50),
#  (6882, 49),
#  (4174, 49),
#  (3679, 49),
#  (1988, 48),
#  (6704, 48),
#  (4655, 48),
#  (1825, 46),
#  (6631, 46),
#  (4760, 44),
#  (6854, 44),
#  (5181, 44),
#  (5591, 44),
#  (5833, 43),
# ...
